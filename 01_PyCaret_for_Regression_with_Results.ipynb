# %% [markdown]
# <a href="https://colab.research.google.com/github/sureshcrwr/Learn-Pycaret/blob/main/01_PyCaret_for_Regression_with_Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# # **PyCaret for Regression**
# ---
# - It is a bundle of many Machine Learning algorithms.
# - Only three lines of code is required to compare 20 ML models.
# - Pycaret is available for:
#     - Classification
#     - Regression
#     - Clustering
# ---
#
# ### **Self learning resource**
# 1. Tutorial on Pycaret **<a href="https://pycaret.readthedocs.io/en/latest/tutorials.html" target="_blank"> Click Here</a>**
#
# 2. Documentation on Pycaret-Regression: **<a href="https://pycaret.readthedocs.io/en/latest/api/regression.html" target="_blank"> Click Here </a>**
#
# ---
#
# ### **In this tutorial we will learn:**
#
# - Getting Data
# - Setting up Environment
# - Create Model
# - Tune Model
# - Plot Model
# - Finalize Model
# - Predict Model
# - Save / Load Model
# ---

# %% [markdown]
# ### **(a) Install Pycaret**

# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %% [markdown]
# ### **(b) Get the version of the pycaret**

# %%
from pycaret.utils import version
version()
# Out:
# '2.3.6'

# %% [markdown]
# ---
# # **1. Regression: Basics**
# ---
# ### **1.1 Get the list of datasets available in pycaret (Total Datasets = 55)**

# %%
from pycaret.datasets import get_data
dataSets = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# 17                         telescope  Multivariate
# 18                           titanic  Multivariate
# 19  us_presidential_election_results  Multivariate
# 20                             glass  Multivariate
# 21                              iris  Multivariate
# 22                             poker  Multivariate
# 23                         questions  Multivariate
# 24                         satellite  Multivariate
# 25                               CTG  Multivariate
# 26                          asia_gdp  Multivariate
# 27                         elections  Multivariate
# 28                          facebook  Multivariate
# 29                               ipl  Multivariate
# 30                         jewellery  Multivariate
# 31                              mice  Multivariate
# 32                         migration  Multivariate
# 33                           perfume  Multivariate
# 34                           pokemon  Multivariate
# 35                        population  Multivariate
# 36                     public_health  Multivariate
# 37                             seeds  Multivariate
# 38                         wholesale  Multivariate
# 39                            tweets          Text
# 40                            amazon          Text
# 41                              kiva          Text
# 42                               spx          Text
# 43                         wikipedia          Text
# 44                        automobile  Multivariate
# 45                              bike  Multivariate
# 46                            boston  Multivariate
# 47                          concrete  Multivariate
# 48                           diamond  Multivariate
# 49                            energy  Multivariate
# 50                            forest  Multivariate
# 51                              gold  Multivariate
# 52                             house  Multivariate
# 53                         insurance  Multivariate
# 54                        parkinsons  Multivariate
# 55                           traffic  Multivariate
#
#                    Default Task Target Variable 1 Target Variable 2  \
# 0             Anomaly Detection              None              None
# 1       Association Rule Mining         InvoiceNo       Description
# 2       Association Rule Mining         InvoiceNo       Description
# 3       Classification (Binary)           deposit              None
# 4       Classification (Binary)             Class              None
# 5       Classification (Binary)             Class              None
# 6       Classification (Binary)           default              None
# 7       Classification (Binary)    Class variable              None
# 8       Classification (Binary)             stabf              None
# 9       Classification (Binary)              left              None
# 10      Classification (Binary)             DEATH              None
# 11      Classification (Binary)           Disease              None
# 12      Classification (Binary)             Class              None
# 13      Classification (Binary)       income >50K              None
# 14      Classification (Binary)          Purchase              None
# 15      Classification (Binary)       TARGET_5Yrs              None
# 16      Classification (Binary)              type              None
# 17      Classification (Binary)             Class              None
# 18      Classification (Binary)          Survived              None
# 19      Classification (Binary)      party_winner              None
# 20  Classification (Multiclass)              Type              None
# 21  Classification (Multiclass)           species              None
# 22  Classification (Multiclass)             CLASS              None
# 23  Classification (Multiclass)     Next_Question              None
# 24  Classification (Multiclass)             Class              None
# 25  Classification (Multiclass)               NSP              None
# 26                   Clustering              None              None
# 27                   Clustering              None              None
# 28                   Clustering              None              None
# 29                   Clustering              None              None
# 30                   Clustering              None              None
# 31                   Clustering              None              None
# 32                   Clustering              None              None
# 33                   Clustering              None              None
# 34                   Clustering              None              None
# 35                   Clustering              None              None
# 36                   Clustering              None              None
# 37                   Clustering              None              None
# 38                   Clustering              None              None
# 39                          NLP             tweet              None
# 40         NLP / Classification        reviewText              None
# 41         NLP / Classification                en              None
# 42             NLP / Regression              text              None
# 43         NLP / Classification              Text              None
# 44                   Regression             price              None
# 45                   Regression               cnt              None
# 46                   Regression              medv              None
# 47                   Regression          strength              None
# 48                   Regression             Price              None
# 49                   Regression      Heating Load      Cooling Load
# 50                   Regression              area              None
# 51                   Regression         Gold_T+22              None
# 52                   Regression         SalePrice              None
# 53                   Regression           charges              None
# 54                   Regression               PPE              None
# 55                   Regression    traffic_volume              None
#
#     # Instances  # Attributes Missing Values
# 0          1000            10              N
# 1          8557             8              N
# 2          9495             8              N
# 3         45211            17              N
# 4           748             5              N
# 5           683            10              N
# 6         24000            24              N
# 7           768             9              N
# 8         10000            14              N
# 9         14999            10              N
# 10          200            16              N
# 11          270            14              N
# 12          154            32              Y
# 13        32561            14              Y
# 14         1070            15              N
# 15         1340            21              N
# 16         6498            13              N
# 17        19020            11              N
# 18          891            11              Y
# 19          497             7              N
# 20          214            10              N
# 21          150             5              N
# 22       100000            11              N
# 23          499             4              N
# 24         6435            37              N
# 25         2129            40              Y
# 26           40            11              N
# 27         3195            54              Y
# 28         7050            12              N
# 29          153            25              N
# 30          505             4              N
# 31         1080            82              Y
# 32          233            12              N
# 33           20            29              N
# 34          800            13              Y
# 35          255            56              Y
# 36          224            21              N
# 37          210             7              N
# 38          440             8              N
# 39         8594             2              N
# 40        20000             2              N
# 41         6818             7              N
# 42          874             4              N
# 43          500             3              N
# 44          202            26              Y
# 45        17379            15              N
# 46          506            14              N
# 47         1030             9              N
# 48         6000             8              N
# 49          768            10              N
# 50          517            13              N
# 51         2558           121              N
# 52         1461            81              Y
# 53         1338             7              N
# 54         5875            22              N
# 55        48204             8              N

# %% [markdown]
# ---
# ### **1.2 Get the "boston" dataset (Step-I)**
# ---

# %%
bostonDataSet = get_data("boston")    # SN is 46
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# ---
# ### **1.3 Parameter setting for all models (Step-II)**
# ---

# %%
from pycaret.regression import *
s = setup(data =  bostonDataSet, target='medv', silent=True)

# Other Parameters:
# train_size = 0.7
# data_split_shuffle = False
# Out:
#                                Description             Value
# 0                               session_id               691
# 1                                   Target              medv
# 2                            Original Data         (506, 14)
# 3                           Missing Values             False
# 4                         Numeric Features                11
# 5                     Categorical Features                 2
# 6                         Ordinal Features             False
# 7                High Cardinality Features             False
# 8                  High Cardinality Method              None
# 9                    Transformed Train Set         (354, 21)
# 10                    Transformed Test Set         (152, 21)
# 11                      Shuffle Train-Test              True
# 12                     Stratify Train-Test             False
# 13                          Fold Generator             KFold
# 14                             Fold Number                10
# 15                                CPU Jobs                -1
# 16                                 Use GPU             False
# 17                          Log Experiment             False
# 18                         Experiment Name  reg-default-name
# 19                                     USI              aec7
# 20                         Imputation Type            simple
# 21          Iterative Imputation Iteration              None
# 22                         Numeric Imputer              mean
# 23      Iterative Imputation Numeric Model              None
# 24                     Categorical Imputer          constant
# 25  Iterative Imputation Categorical Model              None
# 26           Unknown Categoricals Handling    least_frequent
# 27                               Normalize             False
# 28                        Normalize Method              None
# 29                          Transformation             False
# 30                   Transformation Method              None
# 31                                     PCA             False
# 32                              PCA Method              None
# 33                          PCA Components              None
# 34                     Ignore Low Variance             False
# 35                     Combine Rare Levels             False
# 36                    Rare Level Threshold              None
# 37                         Numeric Binning             False
# 38                         Remove Outliers             False
# 39                      Outliers Threshold              None
# 40                Remove Multicollinearity             False
# 41             Multicollinearity Threshold              None
# 42             Remove Perfect Collinearity              True
# 43                              Clustering             False
# 44                    Clustering Iteration              None
# 45                     Polynomial Features             False
# 46                       Polynomial Degree              None
# 47                    Trignometry Features             False
# 48                    Polynomial Threshold              None
# 49                          Group Features             False
# 50                       Feature Selection             False
# 51                Feature Selection Method           classic
# 52            Features Selection Threshold              None
# 53                     Feature Interaction             False
# 54                           Feature Ratio             False
# 55                   Interaction Threshold              None
# 56                        Transform Target             False
# 57                 Transform Target Method           box-cox

# %% [markdown]
# ---
# ### **1.4 Run all models (Step-III)**
# ---

# %%
cm = compare_models()
# Out:
#                                     Model     MAE      MSE    RMSE      R2  \
# gbr           Gradient Boosting Regressor  2.4046  11.1773  3.2490  0.8822
# et                  Extra Trees Regressor  2.2840  11.8246  3.2694  0.8775
# rf                Random Forest Regressor  2.4434  13.0486  3.4711  0.8652
# lightgbm  Light Gradient Boosting Machine  2.4285  13.0568  3.5046  0.8650
# ada                    AdaBoost Regressor  3.0735  19.0580  4.2505  0.8008
# dt                Decision Tree Regressor  3.3371  24.7848  4.8714  0.7416
# lar                Least Angle Regression  3.5996  26.4123  5.0074  0.7228
# lr                      Linear Regression  3.5991  26.4996  5.0170  0.7221
# ridge                    Ridge Regression  3.5691  26.6196  5.0171  0.7218
# br                         Bayesian Ridge  3.5751  27.0489  5.0469  0.7188
# en                            Elastic Net  4.0044  32.1922  5.5608  0.6636
# lasso                    Lasso Regression  4.0020  32.3781  5.5685  0.6624
# huber                     Huber Regressor  3.8434  33.3308  5.5664  0.6597
# omp           Orthogonal Matching Pursuit  4.3877  37.4641  5.9714  0.6086
# knn                 K Neighbors Regressor  4.4972  43.3451  6.4352  0.5414
# par          Passive Aggressive Regressor  6.8890  84.4007  9.1178  0.0834
# llar         Lasso Least Angle Regression  7.1125  94.8074  9.6773 -0.0108
# dummy                     Dummy Regressor  7.1125  94.8074  9.6773 -0.0108
#
#            RMSLE    MAPE  TT (Sec)
# gbr       0.1545  0.1257     0.092
# et        0.1425  0.1135     0.539
# rf        0.1576  0.1247     0.509
# lightgbm  0.1559  0.1229     0.067
# ada       0.2018  0.1666     0.090
# dt        0.2118  0.1670     0.015
# lar       0.2363  0.1852     0.015
# lr        0.2363  0.1851     0.305
# ridge     0.2381  0.1844     0.012
# br        0.2394  0.1847     0.012
# en        0.2549  0.1963     0.013
# lasso     0.2533  0.1967     0.013
# huber     0.2482  0.1875     0.038
# omp       0.3260  0.2266     0.012
# knn       0.2535  0.2144     0.062
# par       0.4723  0.3604     0.012
# llar      0.4163  0.3966     0.012
# dummy     0.4163  0.3966     0.010

# %% [markdown]
# ---
# ### **1.5 "Three line of code" for model comparison for "Boston" dataset**
# ---

# %%
from pycaret.datasets import get_data
from pycaret.regression import *

bostonDataSet = get_data("boston")
setup(data = bostonDataSet, target='medv', silent=True)
cm = compare_models()
# Out:
#                                     Model     MAE      MSE    RMSE      R2  \
# gbr           Gradient Boosting Regressor  2.2887  10.6459  3.2077  0.8568
# et                  Extra Trees Regressor  2.2091  11.3908  3.2762  0.8545
# rf                Random Forest Regressor  2.3540  11.8335  3.3465  0.8463
# lightgbm  Light Gradient Boosting Machine  2.4614  13.5234  3.5368  0.8294
# ada                    AdaBoost Regressor  3.0002  16.9548  4.0242  0.7766
# dt                Decision Tree Regressor  2.9703  17.8744  4.1813  0.7673
# lr                      Linear Regression  3.4560  24.9523  4.8577  0.6907
# lar                Least Angle Regression  3.4560  24.9523  4.8577  0.6907
# ridge                    Ridge Regression  3.4157  25.0157  4.8588  0.6900
# br                         Bayesian Ridge  3.4151  25.6217  4.9149  0.6818
# en                            Elastic Net  3.7376  29.5150  5.2831  0.6345
# lasso                    Lasso Regression  3.8372  30.6497  5.3898  0.6197
# huber                     Huber Regressor  3.8816  35.5125  5.7225  0.5679
# omp           Orthogonal Matching Pursuit  4.2656  35.7143  5.8671  0.5518
# knn                 K Neighbors Regressor  4.2372  40.8770  6.2202  0.4805
# llar         Lasso Least Angle Regression  6.5130  81.2813  8.9526 -0.0374
# dummy                     Dummy Regressor  6.5130  81.2813  8.9526 -0.0374
# par          Passive Aggressive Regressor  7.8362  90.5252  9.3975 -0.1769
#
#            RMSLE    MAPE  TT (Sec)
# gbr       0.1477  0.1168     0.094
# et        0.1439  0.1126     0.444
# rf        0.1521  0.1211     0.510
# lightgbm  0.1547  0.1225     0.038
# ada       0.1919  0.1640     0.093
# dt        0.2001  0.1569     0.018
# lr        0.2329  0.1776     0.012
# lar       0.2329  0.1776     0.016
# ridge     0.2373  0.1761     0.012
# br        0.2422  0.1754     0.013
# en        0.2483  0.1835     0.015
# lasso     0.2508  0.1871     0.014
# huber     0.2681  0.1994     0.039
# omp       0.2787  0.2123     0.013
# knn       0.2490  0.2065     0.061
# llar      0.3971  0.3720     0.012
# dummy     0.3971  0.3720     0.010
# par       0.4388  0.4362     0.014

# %% [markdown]
# ---
# ### **1.6 "Three line of code" for model comparison for "Insurance" dataset**
# ---

# %%
from pycaret.datasets import get_data
from pycaret.regression import *

insuranceDataSet = get_data("insurance")
setup(data = insuranceDataSet, target='charges', silent=True)
cm = compare_models()
# Out:
#                                     Model        MAE           MSE  \
# gbr           Gradient Boosting Regressor  2567.1638  2.095511e+07
# lightgbm  Light Gradient Boosting Machine  2827.7511  2.282086e+07
# rf                Random Forest Regressor  2692.3073  2.306281e+07
# et                  Extra Trees Regressor  2664.1936  2.607449e+07
# ada                    AdaBoost Regressor  4377.5226  2.828103e+07
# llar         Lasso Least Angle Regression  4146.8919  3.537458e+07
# ridge                    Ridge Regression  4162.0191  3.537842e+07
# br                         Bayesian Ridge  4159.6563  3.538185e+07
# lasso                    Lasso Regression  4152.3339  3.538614e+07
# lr                      Linear Regression  4152.2432  3.538683e+07
# lar                Least Angle Regression  4153.5201  3.547908e+07
# huber                     Huber Regressor  3455.0901  4.437155e+07
# dt                Decision Tree Regressor  3258.3525  4.455629e+07
# omp           Orthogonal Matching Pursuit  5673.3838  5.501277e+07
# par          Passive Aggressive Regressor  4490.3261  5.746996e+07
# en                            Elastic Net  7040.5745  8.570253e+07
# knn                 K Neighbors Regressor  7683.4929  1.236665e+08
# dummy                     Dummy Regressor  8663.7003  1.378204e+08
#
#                 RMSE      R2   RMSLE    MAPE  TT (Sec)
# gbr        4537.1000  0.8385  0.4357  0.3091     0.087
# lightgbm   4746.0359  0.8234  0.5255  0.3573     0.049
# rf         4775.5326  0.8213  0.4726  0.3383     0.549
# et         5089.4898  0.7987  0.4756  0.3113     0.542
# ada        5293.0899  0.7814  0.6512  0.7749     0.035
# llar       5905.8770  0.7307  0.5632  0.4305     0.015
# ridge      5906.7560  0.7306  0.5736  0.4330     0.012
# br         5906.9184  0.7306  0.5757  0.4325     0.013
# lasso      5906.8646  0.7305  0.5836  0.4310     0.013
# lr         5906.8977  0.7304  0.5902  0.4310     0.013
# lar        5913.6018  0.7298  0.5902  0.4306     0.015
# huber      6588.4594  0.6643  0.4521  0.2151     0.048
# dt         6631.8801  0.6568  0.5801  0.4227     0.016
# omp        7375.1014  0.5845  0.7247  0.8724     0.013
# par        7516.8480  0.5725  0.5261  0.3660     0.022
# en         9221.0064  0.3602  0.7355  0.9202     0.013
# knn       11053.8927  0.0802  0.8415  0.9684     0.060
# dummy     11673.2337 -0.0209  0.9838  1.4673     0.011

# %% [markdown]
# ---
# # **2. Regression: working with user dataset**
# ---
# ### **2.1 Download the "boston" dataset to local system**
# ---

# %%
bostonDataSet.to_csv("bostonDataSet.csv", index=False)

from google.colab import files
files.download('bostonDataSet.csv')

# %% [markdown]
# ### **2.2 Uploading "user file" from user system**

# %%
from google.colab import files
files.upload()

# %% [markdown]
# ---
# ### **2.3 "Read" the uploaded file**
# ---

# %%
import pandas as pd
myDataSet = pd.read_csv('bostonDataSet (1).csv')
myDataSet.head()

# %% [markdown]
# ---
# ### **2.4 "Compare" the model performance**
# ---

# %%
from pycaret.regression import *
setup(data = myDataSet, target='medv', silent=True)
cm = compare_models()
# Out:
#                                     Model     MAE      MSE    RMSE      R2  \
# gbr           Gradient Boosting Regressor  2.1484   9.8255  2.9977  0.8704
# et                  Extra Trees Regressor  2.2363  12.2422  3.3423  0.8465
# rf                Random Forest Regressor  2.2918  12.4790  3.3461  0.8415
# lightgbm  Light Gradient Boosting Machine  2.3469  13.8349  3.5601  0.8260
# ada                    AdaBoost Regressor  2.8375  16.8532  3.9010  0.7857
# dt                Decision Tree Regressor  3.0314  20.4211  4.3908  0.7206
# lr                      Linear Regression  3.2820  22.4959  4.5906  0.7107
# ridge                    Ridge Regression  3.2715  22.7424  4.6034  0.7092
# br                         Bayesian Ridge  3.3197  23.5006  4.6735  0.7004
# en                            Elastic Net  3.6903  28.9876  5.2467  0.6216
# lasso                    Lasso Regression  3.7309  29.6728  5.3107  0.6126
# lar                Least Angle Regression  3.9939  30.6079  5.4448  0.5873
# huber                     Huber Regressor  3.9220  35.0337  5.6778  0.5606
# omp           Orthogonal Matching Pursuit  4.1166  34.2686  5.7390  0.5473
# knn                 K Neighbors Regressor  4.5205  42.2266  6.3670  0.4421
# llar         Lasso Least Angle Regression  6.2874  77.9630  8.7125 -0.0374
# dummy                     Dummy Regressor  6.2874  77.9630  8.7125 -0.0374
# par          Passive Aggressive Regressor  6.5080  80.2400  8.7445 -0.0476
#
#            RMSLE    MAPE  TT (Sec)
# gbr       0.1400  0.1122     0.092
# et        0.1443  0.1109     0.441
# rf        0.1507  0.1171     0.497
# lightgbm  0.1574  0.1187     0.036
# ada       0.1842  0.1518     0.092
# dt        0.1926  0.1514     0.014
# lr        0.2466  0.1646     0.012
# ridge     0.2572  0.1648     0.012
# br        0.2548  0.1677     0.013
# en        0.2600  0.1789     0.013
# lasso     0.2616  0.1811     0.013
# lar       0.2913  0.2012     0.014
# huber     0.3036  0.1917     0.043
# omp       0.2650  0.2039     0.013
# knn       0.2520  0.2154     0.062
# llar      0.3815  0.3486     0.012
# dummy     0.3815  0.3486     0.011
# par       0.4921  0.3201     0.014

# %% [markdown]
# ---
# ### **2.5 "Three line of code" for model comparison for "user dataset**
# ##### Use it, while working on **"Anaconda/Jupyter notebook"** on local machine
# ---

# %%
from pycaret.regression import *
import pandas as pd

#myDataSet = pd.read_csv("myData.csv")
#s = setup(data = myDataSet, target='cancer'), silent=True)
#cm = compare_models()

# %% [markdown]
# ---
# # **3. Regression: Apply "Data Preprocessing"**
# ---
#
# ### **3.1 Model performance using "Normalization"**

# %%
setup(data = bostonDataSet, target = 'medv', 
      normalize = True, normalize_method = 'zscore', silent=True)
cm = compare_models()

#normalize_method = {zscore, minmax, maxabs, robust}
# Out:
#                                     Model     MAE      MSE    RMSE      R2  \
# et                  Extra Trees Regressor  2.1103  10.8413  3.1397  0.8699
# lightgbm  Light Gradient Boosting Machine  2.3838  13.4614  3.5553  0.8347
# rf                Random Forest Regressor  2.3369  13.6988  3.5639  0.8289
# gbr           Gradient Boosting Regressor  2.3973  13.9839  3.5885  0.8272
# ada                    AdaBoost Regressor  2.7812  15.8669  3.8271  0.8099
# knn                 K Neighbors Regressor  2.8314  17.2390  3.9870  0.7942
# br                         Bayesian Ridge  3.2203  21.1381  4.5061  0.7461
# ridge                    Ridge Regression  3.2654  21.2301  4.5235  0.7441
# lr                      Linear Regression  3.2851  21.3330  4.5373  0.7426
# huber                     Huber Regressor  3.1064  22.4638  4.6184  0.7316
# lasso                    Lasso Regression  3.6533  27.5815  5.1849  0.6707
# en                            Elastic Net  3.7760  29.2818  5.3202  0.6520
# dt                Decision Tree Regressor  3.2876  27.3766  5.0234  0.6457
# par          Passive Aggressive Regressor  4.1437  32.7616  5.5743  0.6091
# lar                Least Angle Regression  3.9767  35.4303  5.4723  0.5771
# omp           Orthogonal Matching Pursuit  4.2318  37.3792  5.9789  0.5604
# llar         Lasso Least Angle Regression  6.7348  85.0686  9.1812 -0.0187
# dummy                     Dummy Regressor  6.7348  85.0686  9.1812 -0.0187
#
#            RMSLE    MAPE  TT (Sec)
# et        0.1372  0.1047     0.449
# lightgbm  0.1559  0.1177     0.039
# rf        0.1539  0.1175     0.512
# gbr       0.1611  0.1219     0.095
# ada       0.1781  0.1473     0.092
# knn       0.1686  0.1350     0.060
# br        0.2387  0.1576     0.013
# ridge     0.2382  0.1597     0.013
# lr        0.2386  0.1607     0.020
# huber     0.2574  0.1485     0.028
# lasso     0.2483  0.1849     0.014
# en        0.2284  0.1865     0.014
# dt        0.2237  0.1665     0.015
# par       0.3312  0.2071     0.017
# lar       0.2627  0.1926     0.016
# omp       0.3433  0.2121     0.014
# llar      0.3875  0.3617     0.012
# dummy     0.3875  0.3617     0.010

# %% [markdown]
# ---
# ### **3.2 Model performance using "Feature Selection"**
# ---

# %%
setup(data = bostonDataSet, target = 'medv', 
      feature_selection = True, feature_selection_method = 'classic',
      feature_selection_threshold = 0.2,  silent=True)
cm = compare_models()

#feature_selection_method = {classic, boruta}
# Out:
#                                     Model     MAE       MSE     RMSE      R2  \
# et                  Extra Trees Regressor  2.1279    9.2280   2.9758  0.8873
# gbr           Gradient Boosting Regressor  2.1761   10.0837   3.1067  0.8709
# rf                Random Forest Regressor  2.2507   11.1237   3.2638  0.8611
# lightgbm  Light Gradient Boosting Machine  2.3960   13.2973   3.5399  0.8399
# ada                    AdaBoost Regressor  2.8914   16.6914   3.9545  0.7939
# dt                Decision Tree Regressor  2.9884   23.3881   4.6771  0.7072
# lr                      Linear Regression  3.6781   27.7681   5.2244  0.6630
# lar                Least Angle Regression  3.7153   27.8564   5.2312  0.6624
# ridge                    Ridge Regression  3.6587   27.9535   5.2396  0.6606
# br                         Bayesian Ridge  3.6988   28.6629   5.3061  0.6526
# en                            Elastic Net  3.9582   31.3829   5.5493  0.6240
# lasso                    Lasso Regression  4.0158   32.2484   5.6214  0.6143
# huber                     Huber Regressor  3.5328   31.9700   5.5778  0.6112
# knn                 K Neighbors Regressor  4.3243   39.1300   6.1647  0.5380
# omp           Orthogonal Matching Pursuit  4.5644   39.3927   6.2212  0.5255
# llar         Lasso Least Angle Regression  6.6826   85.9644   9.1854 -0.0186
# dummy                     Dummy Regressor  6.6826   85.9644   9.1854 -0.0186
# par          Passive Aggressive Regressor  7.9854  127.5817  10.1817 -0.4311
#
#            RMSLE    MAPE  TT (Sec)
# et        0.1334  0.1067     0.407
# gbr       0.1405  0.1104     0.075
# rf        0.1433  0.1120     0.474
# lightgbm  0.1568  0.1201     0.033
# ada       0.1819  0.1520     0.085
# dt        0.1994  0.1461     0.015
# lr        0.2554  0.1861     0.012
# lar       0.2573  0.1887     0.013
# ridge     0.2571  0.1857     0.012
# br        0.2597  0.1870     0.012
# en        0.2582  0.1909     0.014
# lasso     0.2613  0.1930     0.014
# huber     0.3051  0.1837     0.037
# knn       0.2344  0.1937     0.059
# omp       0.2889  0.2141     0.012
# llar      0.3940  0.3653     0.012
# dummy     0.3940  0.3653     0.011
# par       0.4687  0.4247     0.014

# %% [markdown]
# ---
# ### **3.3 Model performance using "Outlier Removal"**
# ---

# %%
setup(data = bostonDataSet, target = 'medv', 
      remove_outliers = True, outliers_threshold = 0.05, silent=True)
cm = compare_models()
# Out:
#                                     Model        MAE           MSE       RMSE  \
# et                  Extra Trees Regressor     2.1521  1.125390e+01     3.2404
# gbr           Gradient Boosting Regressor     2.2362  1.203070e+01     3.3820
# lightgbm  Light Gradient Boosting Machine     2.3899  1.328070e+01     3.5316
# rf                Random Forest Regressor     2.3747  1.435580e+01     3.6619
# ada                    AdaBoost Regressor     2.8459  1.735130e+01     4.0480
# lr                      Linear Regression     3.3940  2.345770e+01     4.7503
# ridge                    Ridge Regression     3.3631  2.374270e+01     4.7739
# br                         Bayesian Ridge     3.4007  2.466560e+01     4.8726
# dt                Decision Tree Regressor     3.2422  2.438790e+01     4.8072
# en                            Elastic Net     3.6929  2.868540e+01     5.2673
# lasso                    Lasso Regression     3.7595  2.974520e+01     5.3648
# huber                     Huber Regressor     3.6748  3.085630e+01     5.4565
# omp           Orthogonal Matching Pursuit     3.9608  3.209870e+01     5.5792
# knn                 K Neighbors Regressor     4.4195  4.380570e+01     6.5060
# llar         Lasso Least Angle Regression     6.4259  8.058160e+01     8.8772
# dummy                     Dummy Regressor     6.4259  8.058160e+01     8.8772
# par          Passive Aggressive Regressor     7.2487  9.282260e+01     9.1779
# lar                Least Angle Regression  5456.4607  7.882904e+08  8882.7241
#
#                     R2   RMSLE      MAPE  TT (Sec)
# et        8.419000e-01  0.1390    0.1066     0.437
# gbr       8.245000e-01  0.1463    0.1121     0.090
# lightgbm  8.092000e-01  0.1509    0.1178     0.035
# rf        7.914000e-01  0.1552    0.1182     0.501
# ada       7.542000e-01  0.1830    0.1497     0.093
# lr        6.825000e-01  0.2303    0.1671     0.027
# ridge     6.799000e-01  0.2370    0.1661     0.031
# br        6.700000e-01  0.2505    0.1690     0.025
# dt        6.294000e-01  0.2048    0.1642     0.015
# en        6.186000e-01  0.2566    0.1781     0.030
# lasso     6.049000e-01  0.2581    0.1797     0.026
# huber     5.878000e-01  0.2742    0.1848     0.056
# omp       5.762000e-01  0.2717    0.1872     0.021
# knn       4.260000e-01  0.2539    0.2077     0.064
# llar     -5.680000e-02  0.3845    0.3524     0.013
# dummy    -5.680000e-02  0.3845    0.3524     0.011
# par      -2.644000e-01  0.4302    0.3946     0.027
# lar      -7.877994e+06  0.9474  230.0780     0.028

# %% [markdown]
# ---
# ### **3.4 Model performance using "Transformation"**
# ---

# %%
setup(data = bostonDataSet, target = 'medv', 
      transformation = True, transformation_method = 'yeo-johnson', silent=True)
cm = compare_models()
# Out:
#                                     Model     MAE      MSE    RMSE      R2  \
# et                  Extra Trees Regressor  2.1143  10.1253  3.0639  0.8748
# gbr           Gradient Boosting Regressor  2.2618  11.5276  3.2864  0.8543
# lightgbm  Light Gradient Boosting Machine  2.3154  12.6017  3.4216  0.8439
# rf                Random Forest Regressor  2.3591  12.9926  3.5089  0.8390
# ada                    AdaBoost Regressor  2.8868  16.5900  3.9525  0.7929
# knn                 K Neighbors Regressor  2.8833  18.9909  4.2014  0.7728
# dt                Decision Tree Regressor  2.9883  19.8997  4.4009  0.7535
# br                         Bayesian Ridge  3.3018  21.1434  4.5405  0.7359
# ridge                    Ridge Regression  3.3474  21.2882  4.5591  0.7333
# lr                      Linear Regression  3.3659  21.3896  4.5712  0.7317
# lar                Least Angle Regression  3.3699  21.4266  4.5757  0.7313
# huber                     Huber Regressor  3.1780  22.0649  4.6439  0.7281
# lasso                    Lasso Regression  3.5969  26.4190  5.0893  0.6760
# en                            Elastic Net  3.6766  29.7999  5.3878  0.6378
# omp           Orthogonal Matching Pursuit  3.9387  30.7385  5.5060  0.6185
# par          Passive Aggressive Regressor  4.3173  36.6718  5.9474  0.5489
# llar         Lasso Least Angle Regression  6.6317  83.4754  9.1035 -0.0198
# dummy                     Dummy Regressor  6.6317  83.4754  9.1035 -0.0198
#
#            RMSLE    MAPE  TT (Sec)
# et        0.1341  0.1057     0.452
# gbr       0.1445  0.1141     0.090
# lightgbm  0.1513  0.1150     0.038
# rf        0.1481  0.1165     0.509
# ada       0.1795  0.1505     0.091
# knn       0.1720  0.1379     0.062
# dt        0.1906  0.1479     0.015
# br        0.2102  0.1642     0.015
# ridge     0.2118  0.1661     0.026
# lr        0.2125  0.1669     0.021
# lar       0.2126  0.1671     0.029
# huber     0.2120  0.1544     0.024
# lasso     0.2128  0.1755     0.022
# en        0.2261  0.1864     0.029
# omp       0.2338  0.1842     0.012
# par       0.3158  0.2176     0.016
# llar      0.3909  0.3636     0.013
# dummy     0.3909  0.3636     0.010

# %% [markdown]
# ---
# ### **3.5 Model performance using "PCA"**
# ---

# %%
setup(data = bostonDataSet, target = 'medv', 
      pca = True, pca_method = 'linear', silent=True)
cm = compare_models()
# Out:
#                                     Model      MAE       MSE     RMSE      R2  \
# rf                Random Forest Regressor   4.0108   36.0516   5.8691  0.5197
# et                  Extra Trees Regressor   4.0347   36.4428   5.8474  0.5186
# gbr           Gradient Boosting Regressor   4.1942   38.6894   6.0971  0.4876
# lightgbm  Light Gradient Boosting Machine   4.3441   39.3173   6.1397  0.4805
# knn                 K Neighbors Regressor   4.5834   42.6438   6.4343  0.4243
# ridge                    Ridge Regression   4.8766   49.2192   6.8763  0.3603
# en                            Elastic Net   4.8777   49.2190   6.8765  0.3603
# lar                Least Angle Regression   4.8766   49.2192   6.8763  0.3603
# lasso                    Lasso Regression   4.8785   49.2198   6.8768  0.3603
# lr                      Linear Regression   4.8766   49.2192   6.8763  0.3603
# br                         Bayesian Ridge   4.8923   49.2628   6.8818  0.3595
# huber                     Huber Regressor   4.6398   50.9673   6.9639  0.3482
# dt                Decision Tree Regressor   4.6555   46.4629   6.7728  0.3426
# omp           Orthogonal Matching Pursuit   5.3466   55.1579   7.3243  0.2738
# ada                    AdaBoost Regressor   5.5212   54.1199   7.2957  0.2599
# llar         Lasso Least Angle Regression   6.3646   77.2514   8.7130 -0.0282
# dummy                     Dummy Regressor   6.3646   77.2514   8.7130 -0.0282
# par          Passive Aggressive Regressor  10.7176  255.9909  15.2366 -2.6780
#
#            RMSLE    MAPE  TT (Sec)
# rf        0.2488  0.2031     0.444
# et        0.2509  0.2044     0.404
# gbr       0.2587  0.2122     0.056
# lightgbm  0.2609  0.2192     0.033
# knn       0.2698  0.2296     0.060
# ridge     0.2835  0.2417     0.040
# en        0.2835  0.2418     0.029
# lar       0.2835  0.2417     0.012
# lasso     0.2835  0.2419     0.023
# lr        0.2835  0.2417     0.019
# br        0.2840  0.2430     0.011
# huber     0.2807  0.2184     0.024
# dt        0.2995  0.2368     0.015
# omp       0.3023  0.2665     0.013
# ada       0.3101  0.2913     0.033
# llar      0.3858  0.3573     0.011
# dummy     0.3858  0.3573     0.010
# par       0.6549  0.5585     0.015

# %% [markdown]
# ---
# ### **3.6 Model performance using "Outlier Removal" + "Normalization"**
# ---

# %%
setup(data = bostonDataSet, target = 'medv', 
      remove_outliers = True, outliers_threshold = 0.05,
      normalize = True, normalize_method = 'zscore', silent=True)
cm = compare_models()
# Out:
#                                     Model     MAE      MSE    RMSE      R2  \
# et                  Extra Trees Regressor  2.1267  10.1527  3.1041  0.8807
# gbr           Gradient Boosting Regressor  2.2723  10.7365  3.1973  0.8695
# rf                Random Forest Regressor  2.2837  11.6284  3.2911  0.8615
# lightgbm  Light Gradient Boosting Machine  2.3401  11.9910  3.3162  0.8606
# ada                    AdaBoost Regressor  2.9253  16.4002  3.9604  0.8007
# knn                 K Neighbors Regressor  2.9041  18.3009  4.1802  0.7892
# dt                Decision Tree Regressor  3.2940  21.8862  4.5680  0.7357
# ridge                    Ridge Regression  3.5112  24.7373  4.9046  0.6976
# lr                      Linear Regression  3.5382  24.8351  4.9148  0.6964
# br                         Bayesian Ridge  3.4791  24.8342  4.9129  0.6961
# lar                Least Angle Regression  3.6293  25.8859  5.0166  0.6847
# huber                     Huber Regressor  3.3137  27.0376  5.0692  0.6720
# lasso                    Lasso Regression  3.9212  31.5736  5.5435  0.6134
# en                            Elastic Net  4.0406  33.7617  5.7069  0.5944
# omp           Orthogonal Matching Pursuit  4.3302  37.9532  6.0942  0.5298
# par          Passive Aggressive Regressor  4.8416  45.5985  6.5221  0.4525
# llar         Lasso Least Angle Regression  6.6770  84.8629  9.1540 -0.0261
# dummy                     Dummy Regressor  6.6770  84.8630  9.1540 -0.0261
#
#            RMSLE    MAPE  TT (Sec)
# et        0.1365  0.1046     0.450
# gbr       0.1488  0.1146     0.091
# rf        0.1482  0.1141     0.516
# lightgbm  0.1482  0.1153     0.036
# ada       0.1869  0.1559     0.091
# knn       0.1713  0.1334     0.061
# dt        0.1946  0.1568     0.014
# ridge     0.2709  0.1684     0.013
# lr        0.2693  0.1694     0.021
# br        0.2714  0.1677     0.014
# lar       0.2756  0.1734     0.016
# huber     0.2901  0.1543     0.025
# lasso     0.2711  0.1935     0.016
# en        0.2412  0.1971     0.014
# omp       0.2937  0.2095     0.013
# par       0.3853  0.2400     0.016
# llar      0.3865  0.3553     0.013
# dummy     0.3865  0.3553     0.010

# %% [markdown]
# ---
# ### **3.7 Model performance using "Outlier Removal" +  "Normalization" + "Transformation"**
# ---

# %%
setup(data = bostonDataSet, target = 'medv',
      remove_outliers = True, outliers_threshold = 0.05, 
      normalize = True, normalize_method = 'zscore',
      transformation = True, transformation_method = 'yeo-johnson', silent=True)
cm = compare_models()
# Out:
#                                     Model     MAE      MSE    RMSE      R2  \
# gbr           Gradient Boosting Regressor  2.1272   8.7308  2.9080  0.8774
# rf                Random Forest Regressor  2.2544  10.6485  3.1808  0.8527
# ada                    AdaBoost Regressor  2.7789  12.5993  3.5115  0.8209
# lightgbm  Light Gradient Boosting Machine  2.3865  12.4014  3.4403  0.8179
# et                  Extra Trees Regressor  2.2537  12.3703  3.3794  0.8169
# knn                 K Neighbors Regressor  2.9633  20.4142  4.3405  0.7409
# dt                Decision Tree Regressor  2.9468  17.5065  4.1087  0.7189
# ridge                    Ridge Regression  3.5663  24.1647  4.8377  0.6762
# lar                Least Angle Regression  3.6393  24.2384  4.8447  0.6755
# lr                      Linear Regression  3.6051  24.2638  4.8474  0.6752
# br                         Bayesian Ridge  3.5467  24.3490  4.8498  0.6746
# huber                     Huber Regressor  3.4990  25.6374  4.9151  0.6738
# lasso                    Lasso Regression  3.8046  29.6747  5.3226  0.6217
# en                            Elastic Net  3.9023  33.2301  5.6008  0.5832
# omp           Orthogonal Matching Pursuit  4.1295  32.4194  5.6027  0.5722
# par          Passive Aggressive Regressor  4.4986  34.4438  5.8353  0.5347
# llar         Lasso Least Angle Regression  6.4610  81.1305  8.8985 -0.0344
# dummy                     Dummy Regressor  6.4610  81.1305  8.8985 -0.0344
#
#            RMSLE    MAPE  TT (Sec)
# gbr       0.1440  0.1110     0.090
# rf        0.1471  0.1158     0.499
# ada       0.1704  0.1489     0.088
# lightgbm  0.1525  0.1180     0.036
# et        0.1482  0.1132     0.444
# knn       0.1805  0.1386     0.062
# dt        0.1899  0.1502     0.015
# ridge     0.2435  0.1838     0.012
# lar       0.2449  0.1870     0.017
# lr        0.2455  0.1856     0.013
# br        0.2421  0.1831     0.014
# huber     0.2460  0.1735     0.030
# lasso     0.2358  0.1909     0.015
# en        0.2432  0.2004     0.014
# omp       0.2702  0.2031     0.012
# par       0.3139  0.2367     0.017
# llar      0.3839  0.3536     0.013
# dummy     0.3839  0.3536     0.011

# %% [markdown]
# ---
# ### **3.8 Explore more parameters of "setup()" on pycaret**
# ---
# - Explore setup() paramaeters in **Step 1.3**
# - **<a href="https://pycaret.readthedocs.io/en/latest/api/regression.html" target="_blank"> Click Here</a>** for more

# %% [markdown]
# ---
# # **4. Regression: More Operations**
# ---
# ### **4.1 Build a single model - "RandomForest"**

# %%
from pycaret.datasets import get_data
from pycaret.regression import *

bostonDataSet = get_data("boston")    # SN is 46
setup(data =  bostonDataSet, target='medv', silent=True)

rfModel = create_model('rf')
# Explore more parameters
# Out:
#          MAE      MSE    RMSE      R2   RMSLE    MAPE
# 0     2.2495  10.5357  3.2459  0.8254  0.1641  0.1264
# 1     1.9797   6.4436  2.5384  0.9189  0.1043  0.0849
# 2     2.4356  28.6386  5.3515  0.6956  0.1751  0.0918
# 3     1.6634   5.2592  2.2933  0.9221  0.1285  0.1050
# 4     1.9100   5.3453  2.3120  0.9368  0.1178  0.0996
# 5     2.2333   8.9163  2.9860  0.9163  0.1420  0.1126
# 6     2.1360   7.0695  2.6589  0.9092  0.1141  0.1016
# 7     1.9165   6.4355  2.5368  0.9431  0.1081  0.0886
# 8     3.9202  33.9762  5.8289  0.5871  0.2624  0.1969
# 9     2.9789  30.1742  5.4931  0.4811  0.2046  0.1598
# Mean  2.3423  14.2794  3.5245  0.8136  0.1521  0.1167
# SD    0.6267  11.0710  1.3629  0.1582  0.0481  0.0339

# %% [markdown]
# ---
# ### **4.2 Other available regression models**
# ---
# -	'ada' - AdaBoost Regressor
# -	'br' - Bayesian Ridge
# -	'dt' - Decision Tree Regressor
# -	'en'	- Elastic Net
# -	'et' - Extra Trees Regressor
# -	'gbr' - Gradient Boosting Regressor
# -	'huber' - Huber Regressor
# -	'knn' - K Neighbors Regressor
# -	'llar' - Lasso Least Angle Regression
# -	'lasso' - Lasso Regression
# -	'lar' - Least Angle Regression
# -	'lightgbm'	- Light Gradient Boosting Machine
# -	'lr' - Linear Regression
# -	'omp' - Orthogonal Matching Pursuit
# -	'par' - Passive Aggressive Regressor
# -	'rf' - Random Forest Regressor
# -	'ridge' - Ridge Regression

# %% [markdown]
# ---
# ### **4.3 Explore more parameters of "create_model()" on pycaret**
# ---
#
# **<a href="https://pycaret.readthedocs.io/en/latest/api/regression.html#pycaret.regression.create_model" target="_blank"> Click Here</a>**

# %% [markdown]
# ---
# ### **4.4 Make prediction on the "new unseen dataset"**
# ---
# #### **Get the "new unseen dataset"**

# %%
# Select top 10 rows from boston dataset
newDataSet = get_data("boston").iloc[:10]
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# #### **Make prediction on "new unseen dataset"**

# %%
newPredictions = predict_model(rfModel, data = newDataSet)
newPredictions
# Out:
#       crim    zn  indus  chas    nox     rm    age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#     black  lstat  medv      Label
# 0  396.90   4.98  24.0  26.562000
# 1  396.90   9.14  21.6  21.290000
# 2  392.83   4.03  34.7  34.718001
# 3  394.63   2.94  33.4  33.719001
# 4  396.90   5.33  36.2  35.655001
# 5  394.12   5.21  28.7  26.934000
# 6  395.60  12.43  22.9  20.528000
# 7  396.90  19.15  27.1  23.994000
# 8  386.63  29.93  16.5  17.770000
# 9  386.71  17.10  18.9  19.118000

# %% [markdown]
# ---
# ### **4.5 "Scatter plot" b/w actual and predicted**
# ---

# %%
import matplotlib.pyplot as plt

predicted = newPredictions.iloc[:,-1]     # Last column
actual = newPredictions.iloc[:,-2]        # 2nd last column

plt.scatter(actual, predicted)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Actul Vs Predicted')
plt.savefig("result-scatter-plot.jpg", dpi=300)
plt.show()

# %% [markdown]
# ---
# ### **4.6 Download the "Scatter plot"**
# ---

# %%
from google.colab import files
files.download('result-scatter-plot.jpg')

# %% [markdown]
# ---
# ### **4.7 "Save" and "Download" the prediction result**
# ---

# %%
from google.colab import files

newPredictions.to_csv("NewPredictions.csv", index=False)
files.download('NewPredictions.csv')

# %% [markdown]
# ---
# ### **4.8 "Save" the trained model**
# ---

# %%
sm = save_model(rfModel, 'rfModelFile')
# Out:
# Transformation Pipeline and Model Successfully Saved

# %% [markdown]
# ---
# ### **4.9 Download the "trained model file" to user local system**
# ---

# %%
from google.colab import files
files.download('rfModelFile.pkl')

# %% [markdown]
# ---
# ### **4.10  "Upload the trained model" --> "Load the model"  --> "Make the prediction" on "new unseen dataset"**
# ---
# ### **4.10.1 Upload the  "Trained Model"**

# %%
from google.colab import files
files.upload()

# %% [markdown]
# ---
# ### **4.10.2 Load the "Model"**
# ---

# %%
rfModel = load_model('rfModelFile (1)')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %% [markdown]
# ---
# ### **4.10.3 Make the prediction on "new unseen dataset"**
# ---

# %%
newPredictions = predict_model(rfModel, data = newDataSet)
newPredictions
# Out:
#       crim    zn  indus  chas    nox     rm    age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#     black  lstat  medv      Label
# 0  396.90   4.98  24.0  26.562000
# 1  396.90   9.14  21.6  21.290000
# 2  392.83   4.03  34.7  34.718001
# 3  394.63   2.94  33.4  33.719001
# 4  396.90   5.33  36.2  35.655001
# 5  394.12   5.21  28.7  26.934000
# 6  395.60  12.43  22.9  20.528000
# 7  396.90  19.15  27.1  23.994000
# 8  386.63  29.93  16.5  17.770000
# 9  386.71  17.10  18.9  19.118000

# %% [markdown]
# ---
# # **5. Plot the trained model**
# ---
# **Following parameters can be plot for a trained model**
#
# - Prediction Error Plot    - 'error'
# - Learning Curve           - 'learning'
# - Validation Curve         - 'vc'
# - Feature Importance       - 'feature'
# - Model Hyperparameter     - 'parameter'

# %% [markdown]
# ---
# ### **5.1 Create RandomForest model or any other model**
# ---

# %%
rfModel = create_model('rf')
# Out:
#          MAE      MSE    RMSE      R2   RMSLE    MAPE
# 0     2.2495  10.5357  3.2459  0.8254  0.1641  0.1264
# 1     1.9797   6.4436  2.5384  0.9189  0.1043  0.0849
# 2     2.4356  28.6386  5.3515  0.6956  0.1751  0.0918
# 3     1.6634   5.2592  2.2933  0.9221  0.1285  0.1050
# 4     1.9100   5.3453  2.3120  0.9368  0.1178  0.0996
# 5     2.2333   8.9163  2.9860  0.9163  0.1420  0.1126
# 6     2.1360   7.0695  2.6589  0.9092  0.1141  0.1016
# 7     1.9165   6.4355  2.5368  0.9431  0.1081  0.0886
# 8     3.9202  33.9762  5.8289  0.5871  0.2624  0.1969
# 9     2.9789  30.1742  5.4931  0.4811  0.2046  0.1598
# Mean  2.3423  14.2794  3.5245  0.8136  0.1521  0.1167
# SD    0.6267  11.0710  1.3629  0.1582  0.0481  0.0339

# %% [markdown]
# ---
# ### **5.2 Plot the "error"**
# ---

# %%
plot_model(rfModel, plot='error')

# %% [markdown]
# ---
# ### **5.3 Plot the "learning curve"**
# ---

# %%
plot_model(rfModel, plot='learning')

# %% [markdown]
# ---
# ### **5.4 Plot the "validation curve"**
# ---

# %%
plot_model(rfModel, plot='vc')

# %% [markdown]
# ---
# ### **5.5 Get the model "parameters"**
# ---

# %%
plot_model(rfModel, plot='parameter')
# Out:
#                          Parameters
# bootstrap                      True
# ccp_alpha                       0.0
# criterion                       mse
# max_depth                      None
# max_features                   auto
# max_leaf_nodes                 None
# max_samples                    None
# min_impurity_decrease           0.0
# min_impurity_split             None
# min_samples_leaf                  1
# min_samples_split                 2
# min_weight_fraction_leaf        0.0
# n_estimators                    100
# n_jobs                           -1
# oob_score                     False
# random_state                   5737
# verbose                           0
# warm_start                    False

# %% [markdown]
# ---
# ### **5.6 Explore the more parameters of "plot_model()" on pycaret**
# ---
# **<a href="https://pycaret.readthedocs.io/en/latest/api/regression.html#pycaret.regression.plot_model" target="_blank"> Click Here </a>**

# %% [markdown]
# ---
# # **6. Feature Importance**
# ---
# ### **6.1 Feature Importance using "Random Forest"**

# %%
rfModel = create_model('rf', verbose=False)
plot_model(rfModel, plot='feature')

# %% [markdown]
# ---
# ### **6.2 Feature Importance using "Extra Trees Regressor"**
# ---

# %%
etModel = create_model('et', verbose=False)
plot_model(etModel, plot='feature')

# %% [markdown]
# ---
# ### **6.3 Feature Importance using "Decision Tree"**
# ---

# %%
dtModel = create_model('dt', verbose=False)
plot_model(dtModel, plot='feature')

# %% [markdown]
# ---
# # **7. Tune/Optimize the model performance**
# ---
# ### **7.1 Train "Decision Tree" with default parameters**

# %%
dtModel = create_model('dt')
# Out:
#          MAE      MSE    RMSE      R2   RMSLE    MAPE
# 0     2.4361  16.5542  4.0687  0.7257  0.2211  0.1593
# 1     3.3611  17.8861  4.2292  0.7748  0.1926  0.1549
# 2     3.0944  32.0872  5.6646  0.6589  0.1962  0.1299
# 3     3.1028  16.6992  4.0865  0.7528  0.2326  0.1923
# 4     2.5600  11.9274  3.4536  0.8589  0.1647  0.1333
# 5     2.4857  13.9486  3.7348  0.8690  0.1565  0.1244
# 6     2.8571  14.7240  3.8372  0.8109  0.1573  0.1294
# 7     2.3743   8.3300  2.8862  0.9264  0.1481  0.1211
# 8     4.1057  41.2226  6.4205  0.4990  0.2872  0.1933
# 9     3.1857  32.4620  5.6975  0.4418  0.2037  0.1599
# Mean  2.9563  20.5841  4.4079  0.7318  0.1960  0.1498
# SD    0.5075  10.2051  1.0746  0.1500  0.0409  0.0254

# %% [markdown]
# #### **Get the "parameters" of Decision Tree**

# %%
plot_model(dtModel, plot='parameter')
# Out:
#                           Parameters
# ccp_alpha                        0.0
# criterion                        mse
# max_depth                       None
# max_features                    None
# max_leaf_nodes                  None
# min_impurity_decrease            0.0
# min_impurity_split              None
# min_samples_leaf                   1
# min_samples_split                  2
# min_weight_fraction_leaf         0.0
# presort                   deprecated
# random_state                    5737
# splitter                        best

# %% [markdown]
# ---
# ### **7.2 Tune "Decision Tree" model**
# ---

# %%
dtModelTuned = tune_model(dtModel, n_iter=200)
# Out:
#          MAE      MSE    RMSE      R2   RMSLE    MAPE
# 0     2.2708  10.1459  3.1853  0.8319  0.1800  0.1218
# 1     2.5375  10.6719  3.2668  0.8656  0.1259  0.1083
# 2     3.0708  33.8497  5.8180  0.6402  0.1978  0.1251
# 3     2.1792   9.8031  3.1310  0.8549  0.1690  0.1286
# 4     2.2757  11.8529  3.4428  0.8598  0.1434  0.1052
# 5     2.2971   9.5856  3.0961  0.9100  0.1391  0.1119
# 6     2.8857  13.4910  3.6730  0.8267  0.1557  0.1303
# 7     2.5486  10.9216  3.3048  0.9035  0.1474  0.1190
# 8     4.7557  42.1178  6.4898  0.4881  0.2950  0.2255
# 9     3.1486  28.0149  5.2929  0.5183  0.2081  0.1627
# Mean  2.7970  18.0454  4.0700  0.7699  0.1762  0.1338
# SD    0.7316  11.3787  1.2166  0.1512  0.0468  0.0341

# %% [markdown]
# #### **Get the "tuned parameters" of Decision Tree**

# %%
plot_model(dtModelTuned, plot='parameter')
# Out:
#                           Parameters
# ccp_alpha                        0.0
# criterion                        mae
# max_depth                          4
# max_features                     1.0
# max_leaf_nodes                  None
# min_impurity_decrease          0.005
# min_impurity_split              None
# min_samples_leaf                   4
# min_samples_split                  5
# min_weight_fraction_leaf         0.0
# presort                   deprecated
# random_state                    5737
# splitter                        best

# %% [markdown]
# ---
# ### **7.3 Explore more parameters of "tune_model()" on pycaret**
# ---
# **<a href="https://pycaret.readthedocs.io/en/latest/api/regression.html#pycaret.regression.tune_model" target="_blank"> Click Here </a>**

# %% [markdown]
# ---
# # **8. AutoML - Advanced Machine Learning**
# ---
#
# - Select n Best Models:
#   - Ensemble, Stacking, Begging, Blending
#   - Auto tune the best n models
#
# **<a href="https://pycaret.readthedocs.io/en/latest/api/regression.html#pycaret.regression.automl" target="_blank">Click Here</a>**

# %% [markdown]
# ---
# # **9. Deploy the model on AWS / Azure**
# ---
# **<a href="https://pycaret.readthedocs.io/en/latest/api/regression.html#pycaret.regression.deploy_model" target="_blank">Click Here</a>**
